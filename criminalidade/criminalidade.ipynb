# %%
library(tidyr)
library(dplyr)
df <- read.csv("dataset.csv")
colnames(df) <- iconv(colnames(df), from = "UTF-8", to = "ASCII//TRANSLIT")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
df %>% group_by(ANO) %>% summarise(MEDIA = round(mean(ROUBOS, na.rm = TRUE)))
# Out:
#    ANO  MEDIA
# 1  2001 115
# 2  2002 117
# 3  2003 140
# 4  2004 140
# 5  2005 136
# 6  2006 139
# 7  2007 136
# 8  2008 113
# 9  2009 146
# 10 2010 147
# 11 2011 159
# 12 2012 156
# 13 2013 167
# 14 2014 189
# 15 2015 166
# 16 2016 173
# 17 2017 170
# 18 2018 139
# 19 2019 129
# 20 2020 106
# 21 2021 100
# 22 2022 111
# 23 2023 127
# 24 2024  95
# 25 2025  94

# %%
library(dplyr)
library(ggplot2)

df %>%
  group_by(ANO) %>%
  summarise(MEDIA = round(mean(ROUBOS, na.rm = TRUE))) %>%
  ggplot(aes(x = ANO, y = MEDIA)) +
  geom_line() +
  geom_point() +
  labs(
    title = "Média de Roubos por Ano",
    x = "Ano",
    y = "Média de Roubos"
  ) +
  theme_minimal()
# Out:
# plot without title

# %%
df %>% group_by(ANO) %>% summarise(MEDIANA = median(ROUBOS, na.rm = TRUE))
# Out:
#    ANO  MEDIANA
# 1  2001 51.5
# 2  2002 63.0
# 3  2003 54.0
# 4  2004 55.5
# 5  2005 64.0
# 6  2006 61.0
# 7  2007 62.5
# 8  2008 49.0
# 9  2009 72.5
# 10 2010 80.0
# 11 2011 95.0
# 12 2012 81.5
# 13 2013 81.0
# 14 2014 90.5
# 15 2015 93.0
# 16 2016 87.0
# 17 2017 88.5
# 18 2018 73.5
# 19 2019 77.5
# 20 2020 55.0
# 21 2021 58.5
# 22 2022 49.5
# 23 2023 53.5
# 24 2024 43.0
# 25 2025 42.5

# %%
df %>%
  group_by(ANO) %>%
  summarise(
    MODA = as.numeric(
      names(which.max(table(ROUBOS)))
    )
  )
# Out:
#    ANO  MODA
# 1  2001 36
# 2  2002 12
# 3  2003 22
# 4  2004 45
# 5  2005 23
# 6  2006 59
# 7  2007 28
# 8  2008 21
# 9  2009 50
# 10 2010 42
# 11 2011 15
# 12 2012 27
# 13 2013 27
# 14 2014 43
# 15 2015 27
# 16 2016 40
# 17 2017 38
# 18 2018 52
# 19 2019 27
# 20 2020 32
# 21 2021 29
# 22 2022 24
# 23 2023 33
# 24 2024 31
# 25 2025 31

# %%
df %>% group_by(ANO) %>% reframe(DESVIO = ROUBOS - mean(ROUBOS, na.rm = TRUE))
# Out:
#      ANO  DESVIO
# 1    2001 -102.31481
# 2    2001 -103.31481
# 3    2001 -108.31481
# 4    2001 -109.31481
# 5    2001 -106.31481
# 6    2001 -109.31481
# 7    2001 -103.31481
# 8    2001 -104.31481
# 9    2001  -98.31481
# 10   2001 -107.31481
# 11   2001 -107.31481
# 12   2001 -105.31481
# 13   2001  -65.31481
# 14   2001  -68.31481
# 15   2001  -63.31481
# 16   2001  -64.31481
# 17   2001  -81.31481
# 18   2001  -82.31481
# 19   2001  -52.31481
# 20   2001  -68.31481
# 21   2001  -54.31481
# 22   2001  -71.31481
# 23   2001  -68.31481
# 24   2001  -60.31481
# 25   2001   68.68519
# 26   2001   40.68519
# 27   2001  141.68519
# 28   2001  143.68519
# 29   2001   80.68519
# 30   2001   64.68519
# ⋮    ⋮    ⋮
# 2671 2025 111.10185
# 2672 2025 111.10185
# 2673 2025 140.10185
# 2674 2025 127.10185
# 20 2020  59.3040
# 21 2021  54.1149
# 22 2022  40.0302
# 23 2023  48.1845
# 24 2024  39.2889
# 25 2025  43.7367

# %%
df %>% group_by(ANO) %>% summarise(AMPLITUDE = diff(range(ROUBOS)))
# Out:
#    ANO  AMPLITUDE
# 1  2001 323
# 2  2002 655
# 3  2003 478
# 4  2004 534
# 5  2005 483
# 6  2006 496
# 7  2007 424
# 8  2008 439
# 9  2009 427
# 10 2010 412
# 11 2011 421
# 12 2012 430
# 13 2013 396
# 14 2014 599
# 15 2015 401
# 16 2016 374
# 17 2017 491
# 18 2018 419
# 19 2019 346
# 20 2020 356
# 21 2021 277
# 22 2022 336
# 23 2023 348
# 24 2024 233
# 25 2025 235

# %%
df %>% group_by(ANO) %>% summarise(QUANTIL = quantile(ROUBOS, probs = 0.9))
# Out:
#    ANO  QUANTIL
# 1  2001 254.6
# 2  2002 256.7
# 3  2003 349.1
# 4  2004 356.3
# 5  2005 319.0
# 6  2006 323.3
# 7  2007 330.0
# 8  2008 284.3
# 9  2009 326.6
# 10 2010 318.2
# 11 2011 339.9
# 12 2012 326.9
# 13 2013 356.6
# 14 2014 405.3
# 15 2015 330.9
# 16 2016 346.6
# 17 2017 332.6
# 18 2018 284.9
# 19 2019 255.6
# 20 2020 219.3
# 21 2021 204.3
# 22 2022 225.8
# 23 2023 272.3
# 24 2024 206.0
# 25 2025 206.0

# %%
# Out:
#     Bertioga      Cubatão      Guarujá     Itanhaém     Mongaguá      Peruíbe
#    0.1111111    0.1111111    0.1111111    0.1111111    0.1111111    0.1111111
# Praia Grande       Santos  São Vicente
#    0.1111111    0.1111111    0.1111111

# %%
plot(density(df$ROUBOS), main = "DENSIDADE - TOTAL DE ROUBOS", col = "blue")
# Out:
# Plot with title “DENSIDADE - TOTAL DE ROUBOS”

# %%
boxplot(df$ROUBOS,
main = "Box Plot - Total de Roubos",
ylab = "Valores",
col = "lightblue",
border = "darkblue",
outline = FALSE,
notch = F)
# Out:
# Plot with title “Box Plot - Total de Roubos”

# %%
roubos <- df$ROUBOS

hist(roubos,
     col = "lightblue",
     main = "Histograma Total de Roubos",
     xlab = "Roubos")
# Out:
# Plot with title “Histograma Total de Roubos”

# %%
install.packages("fitdistrplus")
library(fitdistrplus)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: MASS
#
#
# Attaching package: ‘MASS’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# Loading required package: survival

# %%
ajuste <- fitdist(df$ROUBOS, "lnorm")
plot(ajuste)
# Out:
# Plot with title “P-P plot”

# %%
install.packages(fitdistrplus)
# Out:
# Error: object 'fitdistrplus' not found
# Traceback:
#
# 1. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'fitdistrplus' not found", base::quote(eval(expr,
#  .     envir)))

# %%
library(fitdistrplus)

ajuste_norm <- fitdist(df$ROUBOS, "norm")

ajuste_norm$estimate
summary(ajuste_norm)
plot(ajuste_norm)
# Out:
#     mean       sd
# 136.4252 119.5151
# Fitting of the distribution ' norm ' by maximum likelihood
# Parameters :
#      estimate Std. Error
# mean 136.4252   2.300073
# sd   119.5151   1.626396
# Loglikelihood:  -16746.43   AIC:  33496.86   BIC:  33508.66
# Correlation matrix:
#      mean sd
# mean    1  0
# sd      0  1
# Plot with title “P-P plot”

# %%
x <- df$ROUBOS
hist(x, breaks = 20, probability = TRUE, col = "lightblue",
     main = "Histograma e curva normal ajustada", xlab = "x")

x_seq <- seq(min(x), max(x), length.out = 200)

lines(x_seq, dnorm(x_seq, mean = ajuste_norm$estimate["mean"],
                         sd   = ajuste_norm$estimate["sd"]),
      col = "red", lwd = 2)
# Out:
# Plot with title “Histograma e curva normal ajustada”
